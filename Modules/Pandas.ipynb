# %%
import pandas as pd

d = {
     'name': ['Sapta','Rima','Deb'], 
     'mark': [67,98,45]}

df1 = pd.DataFrame(d, index=[11,12,13])

print(df1)
# Out:
#      name  mark
# 11  Sapta    67
# 12   Rima    98
# 13    Deb    45
